# %%
# %matplotlib inline

# %%
# Dependencies

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# Ignore Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
# Take in all of our name data (.csv files) and read it into pandas

yob1991 = "DATA SET/yob1991.csv"
yob1992 = "DATA SET/yob1992.csv"
yob1993 = "DATA SET/yob1993.csv"
yob1994 = "DATA SET/yob1994.csv"
yob1995 = "DATA SET/yob1995.csv"
yob1996 = "DATA SET/yob1996.csv"
yob1997 = "DATA SET/yob1997.csv"
yob1998 = "DATA SET/yob1998.csv"
yob1999 = "DATA SET/yob1999.csv"
yob2000 = "DATA SET/yob2000.csv"
yob2001 = "DATA SET/yob2001.csv"
yob2002 = "DATA SET/yob2002.csv"
yob2003 = "DATA SET/yob2003.csv"
yob2004 = "DATA SET/yob2004.csv"
yob2005 = "DATA SET/yob2005.csv"
yob2006 = "DATA SET/yob2006.csv"
yob2007 = "DATA SET/yob2007.csv"
yob2008 = "DATA SET/yob2008.csv"
yob2009 = "DATA SET/yob2009.csv"
yob2010 = "DATA SET/yob2010.csv"
yob2011 = "DATA SET/yob2011.csv"
yob2012 = "DATA SET/yob2012.csv"
yob2013 = "DATA SET/yob2013.csv"
yob2014 = "DATA SET/yob2014.csv"
yob2015 = "DATA SET/yob2015.csv"
yob2016 = "DATA SET/yob2016.csv"
yob2017 = "DATA SET/yob2017.csv"
yob2018 = "DATA SET/yob2018.csv"

# Create dataframes for each .csv file (e.g. df for each year from 1991 to 2018)

yob1991_df = pd.read_csv(yob1991)
yob1992_df = pd.read_csv(yob1992)
yob1993_df = pd.read_csv(yob1993)
yob1994_df = pd.read_csv(yob1994)
yob1995_df = pd.read_csv(yob1995)
yob1996_df = pd.read_csv(yob1996)
yob1997_df = pd.read_csv(yob1997)
yob1998_df = pd.read_csv(yob1998)
yob1999_df = pd.read_csv(yob1999)
yob2000_df = pd.read_csv(yob2000)
yob2001_df = pd.read_csv(yob2001)
yob2002_df = pd.read_csv(yob2002)
yob2003_df = pd.read_csv(yob2003)
yob2004_df = pd.read_csv(yob2004)
yob2005_df = pd.read_csv(yob2005)
yob2006_df = pd.read_csv(yob2006)
yob2007_df = pd.read_csv(yob2007)
yob2008_df = pd.read_csv(yob2008)
yob2009_df = pd.read_csv(yob2009)
yob2010_df = pd.read_csv(yob2010)
yob2011_df = pd.read_csv(yob2011)
yob2012_df = pd.read_csv(yob2012)
yob2013_df = pd.read_csv(yob2013)
yob2014_df = pd.read_csv(yob2014)
yob2015_df = pd.read_csv(yob2015)
yob2016_df = pd.read_csv(yob2016)
yob2017_df = pd.read_csv(yob2017)
yob2018_df = pd.read_csv(yob2018)

# %%
# Create a header to each df

yob1991_df.columns =['Name', 'Gender', 'Count']
yob1992_df.columns =['Name', 'Gender', 'Count']
yob1993_df.columns =['Name', 'Gender', 'Count']
yob1994_df.columns =['Name', 'Gender', 'Count']
yob1995_df.columns =['Name', 'Gender', 'Count']
yob1996_df.columns =['Name', 'Gender', 'Count']
yob1997_df.columns =['Name', 'Gender', 'Count']
yob1998_df.columns =['Name', 'Gender', 'Count']
yob1999_df.columns =['Name', 'Gender', 'Count']
yob2000_df.columns =['Name', 'Gender', 'Count']
yob2001_df.columns =['Name', 'Gender', 'Count']
yob2002_df.columns =['Name', 'Gender', 'Count']
yob2003_df.columns =['Name', 'Gender', 'Count']
yob2004_df.columns =['Name', 'Gender', 'Count']
yob2005_df.columns =['Name', 'Gender', 'Count']
yob2006_df.columns =['Name', 'Gender', 'Count']
yob2007_df.columns =['Name', 'Gender', 'Count']
yob2008_df.columns =['Name', 'Gender', 'Count']
yob2009_df.columns =['Name', 'Gender', 'Count']
yob2010_df.columns =['Name', 'Gender', 'Count']
yob2011_df.columns =['Name', 'Gender', 'Count']
yob2012_df.columns =['Name', 'Gender', 'Count']
yob2013_df.columns =['Name', 'Gender', 'Count']
yob2014_df.columns =['Name', 'Gender', 'Count']
yob2015_df.columns =['Name', 'Gender', 'Count']
yob2016_df.columns =['Name', 'Gender', 'Count']
yob2017_df.columns =['Name', 'Gender', 'Count']
yob2018_df.columns =['Name', 'Gender', 'Count']

# %%
# Merge the first two datasets on "Name" 
combined_name_df = pd.merge(yob1991_df, yob1992_df, how='outer', on=['Name', 'Gender'])
# Rename our _x and _y columns to "Count 1991", "Count 1992"
combined_name_df = combined_name_df.rename(columns={"Count_x":"Count 1991", "Count_y": "Count 1992"})

# Merge combined data with dataset 1993
combined_name_df = pd.merge(combined_name_df, yob1993_df, how='outer', on=['Name', 'Gender'])
# Rename columns 
combined_name_df = combined_name_df.rename(columns={"Count":"Count 1993"})

# Merge combined data with dataset 1994
combined_name_df = pd.merge(combined_name_df, yob1994_df, how='outer', on=['Name', 'Gender'])
# Rename columns
combined_name_df = combined_name_df.rename(columns={"Count":"Count 1994"})

# Merge combined data with dataset 1995
combined_name_df = pd.merge(combined_name_df, yob1995_df, how='outer', on=['Name', 'Gender'])
# Rename columns
combined_name_df = combined_name_df.rename(columns={"Count":"Count 1995"})

# Merge combined data with dataset 1996
combined_name_df = pd.merge(combined_name_df, yob1996_df, how='outer', on=['Name', 'Gender'])
# Rename columns
combined_name_df = combined_name_df.rename(columns={"Count":"Count 1996"})

# Merge combined data with dataset 1997
combined_name_df = pd.merge(combined_name_df, yob1997_df, how='outer', on=['Name', 'Gender'])
# Rename columns
combined_name_df = combined_name_df.rename(columns={"Count":"Count 1997"})

# Merge combined data with dataset 1998
combined_name_df = pd.merge(combined_name_df, yob1998_df, how='outer', on=['Name', 'Gender'])
# Rename columns
combined_name_df = combined_name_df.rename(columns={"Count":"Count 1998"})

# Merge combined data with dataset 1999
combined_name_df = pd.merge(combined_name_df, yob1999_df, how='outer', on=['Name', 'Gender'])
# Rename columns
combined_name_df = combined_name_df.rename(columns={"Count":"Count 1999"})

# %%
# Merge combined data with dataset 2000
combined_name_df = pd.merge(combined_name_df, yob2000_df, how='outer', on=['Name', 'Gender'])
# Rename columns
combined_name_df = combined_name_df.rename(columns={"Count":"Count 2000"})

# Merge combined data with dataset 2001
combined_name_df = pd.merge(combined_name_df, yob2001_df, how='outer', on=['Name', 'Gender'])
# Rename columns
combined_name_df = combined_name_df.rename(columns={"Count":"Count 2001"})

# Merge combined data with dataset 2002
combined_name_df = pd.merge(combined_name_df, yob2002_df, how='outer', on=['Name', 'Gender'])
# Rename columns
combined_name_df = combined_name_df.rename(columns={"Count":"Count 2002"})

# Merge combined data with dataset 2003
combined_name_df = pd.merge(combined_name_df, yob2003_df, how='outer', on=['Name', 'Gender'])
# Rename columns
combined_name_df = combined_name_df.rename(columns={"Count":"Count 2003"})

# Merge combined data with dataset 2004
combined_name_df = pd.merge(combined_name_df, yob2004_df, how='outer', on=['Name', 'Gender'])
# Rename columns
combined_name_df = combined_name_df.rename(columns={"Count":"Count 2004"})

# Merge combined data with dataset 2005
combined_name_df = pd.merge(combined_name_df, yob2005_df, how='outer', on=['Name', 'Gender'])
# Rename columns
combined_name_df = combined_name_df.rename(columns={"Count":"Count 2005"})

# Merge combined data with dataset 2006
combined_name_df = pd.merge(combined_name_df, yob2002_df, how='outer', on=['Name', 'Gender'])
# Rename columns
combined_name_df = combined_name_df.rename(columns={"Count":"Count 2006"})

# Merge combined data with dataset 2007
combined_name_df = pd.merge(combined_name_df, yob2007_df, how='outer', on=['Name', 'Gender'])
# Rename columns
combined_name_df = combined_name_df.rename(columns={"Count":"Count 2007"})

# Merge combined data with dataset 2008
combined_name_df = pd.merge(combined_name_df, yob2008_df, how='outer', on=['Name', 'Gender'])
# Rename columns
combined_name_df = combined_name_df.rename(columns={"Count":"Count 2008"})

# %%
# Merge combined data with dataset 2009
combined_name_df = pd.merge(combined_name_df, yob2009_df, how='outer', on=['Name', 'Gender'])
# Rename columns
combined_name_df = combined_name_df.rename(columns={"Count":"Count 2009"})

# Merge combined data with dataset 2010
combined_name_df = pd.merge(combined_name_df, yob2010_df, how='outer', on=['Name', 'Gender'])
# Rename columns
combined_name_df = combined_name_df.rename(columns={"Count":"Count 2010"})

# Merge combined data with dataset 2011
combined_name_df = pd.merge(combined_name_df, yob2011_df, how='outer', on=['Name', 'Gender'])
# Rename columns
combined_name_df = combined_name_df.rename(columns={"Count":"Count 2011"})

# Merge combined data with dataset 2012
combined_name_df = pd.merge(combined_name_df, yob2012_df, how='outer', on=['Name', 'Gender'])
# Rename columns
combined_name_df = combined_name_df.rename(columns={"Count":"Count 2012"})

# Merge combined data with dataset 2013
combined_name_df = pd.merge(combined_name_df, yob2013_df, how='outer', on=['Name', 'Gender'])
# Rename columns
combined_name_df = combined_name_df.rename(columns={"Count":"Count 2013"})

# Merge combined data with dataset 2014
combined_name_df = pd.merge(combined_name_df, yob2014_df, how='outer', on=['Name', 'Gender'])
# Rename columns
combined_name_df = combined_name_df.rename(columns={"Count":"Count 2014"})

# Merge combined data with dataset 2015
combined_name_df = pd.merge(combined_name_df, yob2015_df, how='outer', on=['Name', 'Gender'])
# Rename columns
combined_name_df = combined_name_df.rename(columns={"Count":"Count 2015"})

# Merge combined data with dataset 2016
combined_name_df = pd.merge(combined_name_df, yob2016_df, how='outer', on=['Name', 'Gender'])
# Rename columns
combined_name_df = combined_name_df.rename(columns={"Count":"Count 2016"})

# Merge combined data with dataset 2017
combined_name_df = pd.merge(combined_name_df, yob2017_df, how='outer', on=['Name', 'Gender'])
# Rename columns
combined_name_df = combined_name_df.rename(columns={"Count":"Count 2017"})

# Merge combined data with dataset 2018
combined_name_df = pd.merge(combined_name_df, yob2018_df, how='outer', on=['Name', 'Gender'])
# Rename columns
combined_name_df = combined_name_df.rename(columns={"Count":"Count 2018"})

# %%
# Replace NaN in df with the value zero
combined_name_df = combined_name_df.fillna(0)

# Sort combined df in alphabetical order by "Name"
combined_name_df.sort_values(by=['Name'], inplace=True)

# Save combined_name_df to a csv file
combined_name_df.to_csv(r'DATA SET/Combined_Names_1991_2018.csv')

# Print df
#combined_name_df

# %%
# Search through df for GOT male character names

# Jon and Jaimie are GOT male character names 
# that we decided to not include because 
# those are popular names regardless of any GOT influence

male_names_df = combined_name_df[(combined_name_df['Name'] == "Joffrey") | 
                 (combined_name_df['Name'] == "Jorah") | 
                 (combined_name_df['Name'] == "Bran") | 
                 (combined_name_df['Name'] == "Theon") | 
                 (combined_name_df['Name'] == "Tyrion") | 
                 (combined_name_df['Name'] == "Davos") | 
                 (combined_name_df['Name'] == "Stannis") | 
                 (combined_name_df['Name'] == "Bronn") | 
                 (combined_name_df['Name'] == "Stark") | 
                 (combined_name_df['Name'] == "Ramsay")]

# Sort df in alphabetical order by "Name"
male_names_df.sort_values('Name', ascending=True)

# Print df
male_names_df
# Out:
#           Name Gender  Count 1991  Count 1992  Count 1993  Count 1994  \
# 51037     Bran      M         0.0         0.0         0.0         0.0
# 80988    Bronn      M         0.0         0.0         0.0         0.0
# 22339  Joffrey      M         7.0         0.0         0.0         0.0
# 78153    Jorah      M         0.0         0.0         0.0         0.0
# 49310    Jorah      F         0.0         0.0         0.0         0.0
# 28817   Ramsay      M         0.0         8.0         0.0         8.0
# 42408   Ramsay      F         0.0         0.0         0.0         0.0
# 72058    Stark      M         0.0         0.0         0.0         0.0
# 22657    Theon      M         7.0         0.0         0.0         0.0
# 44354   Tyrion      M         0.0         0.0         0.0         0.0
# 44706   Tyrion      F         0.0         0.0         0.0         0.0
#
#        Count 1995  Count 1996  Count 1997  Count 1998  ...  Count 2009  \
# ...

# %%
# Create a new column named "Total Count"
# Calculate the total count of each GOT name throughout the years 1991 - 2018

def total_male_name_count(df, new_column, years):
    df[new_column] = df[years].astype(float).sum(axis=1)
    return(df)
total_male_name_count(male_names_df, 'Total Count', ['Count 1991','Count 1992','Count 1993', 'Count 1994', 'Count 1995',
                                                        'Count 1996', 'Count 1997', 'Count 1998', 'Count 1999', 'Count 2000',
                                                        'Count 2001', 'Count 2002', 'Count 2003', 'Count 2004', 'Count 2005',
                                                        'Count 2006', 'Count 2007', 'Count 2008', 'Count 2009', 'Count 2010',
                                                        'Count 2011', 'Count 2012', 'Count 2013', 'Count 2014', 'Count 2015',
                                                        'Count 2016', 'Count 2017', 'Count 2018'])


# Copy male_names_df to a new df
male_names_total = male_names_df

# Print columns 'Name' and 'Total Count' only
male_names_total = male_names_total[['Name','Total Count']]

# Combine total counts for duplicate names (e.g. Arya)
male_names_total = male_names_total.groupby(['Name']).agg({'Total Count': 'sum'})

# Sort df in ascending order by "Total Count"
male_names_total.sort_values('Total Count', ascending=False, inplace=True)

# Save male_names_total to a csv file
male_names_total.to_csv(r'DATA SET/GOT_Male_Names_1991_2018.csv')

# Print df
male_names_total
# Out:
#          Total Count
# Name
# Tyrion         550.0
# Ramsay         239.0
# Theon          139.0
# Stark          134.0
# Jorah          112.0
# Bran           103.0
# Bronn           20.0
# Joffrey          7.0

# %%
# Configure plot and ticks
# Create the bar graph for total count of all male GOT names
male_names_total.plot(kind="bar", facecolor="blue", alpha=0.5, align="center")
plt.title('Popular Male "GOT" Names')
plt.ylabel("Total Name Count")
plt.xlabel("Male Character Names")

# Resize plot to display labels
plt.tight_layout()

# %%
# Sorting the df by descending order
male_names_df.sort_values('Total Count', ascending=False, inplace=True)

# Creating top 3 male names df
top3_male_names = male_names_df.iloc[:3]

# Set index to "Name"
top3_male_names = top3_male_names.set_index("Name")

# Rename count colums
top3_male_names = top3_male_names.rename(columns={'Count 1991': '1991', 'Count 1992': '1992', 'Count 1993':'1993',
                                                   'Count 1994': '1994', 'Count 1995': '1995', 'Count 1996': '1996',
                                                   'Count 1997': '1997', 'Count 1998': '1998', 'Count 1999': '1999', 
                                                   'Count 2000': '2000', 'Count 2001': '2001', 'Count 2002':'2002', 
                                                   'Count 2003': '2003', 'Count 2004': '2004', 'Count 2005': '2005',
                                                   'Count 2006': '2006', 'Count 2007': '2007', 'Count 2008': '2008', 
                                                   'Count 2009': '2009', 'Count 2010': '2010', 'Count 2011': '2011', 
                                                   'Count 2012': '2012', 'Count 2013': '2013', 'Count 2014': '2014', 
                                                   'Count 2015': '2015', 'Count 2016': '2016', 'Count 2017': '2017', 
                                                   'Count 2018': '2018'})

top3_male_names

# Collect the years where the data was collected
yearly_count= top3_male_names
years= yearly_count.keys()

# Tyrion total count line
top3_male_names.loc['Tyrion', "1991":"2018"].plot(label="Tyrion")
plt.legend()

# Ramsay total count line
top3_male_names.loc['Ramsay', "1991":"2018"].plot(label="Ramsay")
plt.legend()

# Theon total count line

top3_male_names.loc['Theon', "1991":"2018"].plot(label="Theon")
plt.legend()


# Add labels andtitle
plt.title('TOP 3 "GOT" Male Names')
plt.xlabel("Years")
plt.ylabel("Total Count")

# Show the chart
plt.show()

# %%
# Search through df for GOT female character names
female_names_df = combined_name_df[(combined_name_df['Name'] == "Cersei") | 
                 (combined_name_df['Name'] == "Khaleesi") | 
                 (combined_name_df['Name'] == "Sansa") | 
                 (combined_name_df['Name'] == "Arya") | 
                 (combined_name_df['Name'] == "Melisandre") | 
                 (combined_name_df['Name'] == "Margaery") | 
                 (combined_name_df['Name'] == "Brienne") | 
                 (combined_name_df['Name'] == "Lyanna") | 
                 (combined_name_df['Name'] == "Meera") | 
                 (combined_name_df['Name'] == "Daenerys")]

# Sort df in ascending order by "Name"
female_names_df.sort_values('Name', ascending=True)

# Print df
female_names_df
# Out:
#            Name Gender  Count 1991  Count 1992  Count 1993  Count 1994  \
# 25845      Arya      F         0.0         7.0         0.0         0.0
# 17605      Arya      M        34.0        29.0        26.0        15.0
# 4070    Brienne      F        25.0        21.0        26.0        22.0
# 81543    Cersei      F         0.0         0.0         0.0         0.0
# 73888  Daenerys      F         0.0         0.0         0.0         0.0
# 72127  Khaleesi      F         0.0         0.0         0.0         0.0
# 12436    Lyanna      F         6.0        10.0         8.0         8.0
# 3505      Meera      F        31.0        36.0        31.0        38.0
# 75626     Sansa      F         0.0         0.0         0.0         0.0
#
#        Count 1995  Count 1996  Count 1997  Count 1998  ...  Count 2009  \
# 25845         0.0        11.0        13.0        25.0  ...       237.0
# 17605        30.0        25.0        31.0        33.0  ...       113.0
# ...

# %%
# Create a new column named "Total Count"
# Calculate the total count of each GOT name throughout the years 1991 - 2018

def total_female_name_count(df, new_column, years):
    df[new_column] = df[years].astype(float).sum(axis=1)
    return(df)

total_female_name_count(female_names_df, 'Total Count', ['Count 1991','Count 1992','Count 1993', 'Count 1994', 'Count 1995',
                                                        'Count 1996', 'Count 1997', 'Count 1998', 'Count 1999', 'Count 2000',
                                                        'Count 2001', 'Count 2002', 'Count 2003', 'Count 2004', 'Count 2005',
                                                        'Count 2006', 'Count 2007', 'Count 2008', 'Count 2009', 'Count 2010',
                                                        'Count 2011', 'Count 2012', 'Count 2013', 'Count 2014', 'Count 2015',
                                                        'Count 2016', 'Count 2017', 'Count 2018'])


# Copy female_names_df to a new df
female_names_total = female_names_df

# Print columns 'Name' and 'Total Count' only
female_names_total = female_names_total[['Name','Total Count']]

# Combine total counts for duplicate names (e.g. Arya)
female_names_total = female_names_total.groupby(['Name']).agg({'Total Count': 'sum'})

# Sort df in ascending order by "Total Count"
female_names_total.sort_values('Total Count', ascending=False, inplace=True)

# Save female_names_total to a csv file
female_names_total.to_csv(r'DATA SET/GOT_Female_Names_1991_2018.csv')

#Print df
female_names_total
# Out:
#           Total Count
# Name
# Arya          15318.0
# Khaleesi       2528.0
# Meera          2446.0
# Lyanna         1521.0
# Daenerys        631.0
# Brienne         590.0
# Sansa           118.0
# Cersei           11.0

# %%
# Configure plot and ticks
# Create the bar graph for total count of all female GOT names
female_names_total.plot(kind="bar", facecolor="purple", alpha=0.5, align="center")
plt.title('Popular Female "GOT" Names')
plt.ylabel("Total Name Count")
plt.xlabel("Female Character Names")

# Resize plot to display labels
plt.tight_layout()

# %%
# Sorting the df by descending order
female_names_df.sort_values('Total Count', ascending=False, inplace=True)

# Creating top 3 female names df
top3_female_names = female_names_df.iloc[:3]

# Set index to "Name"
top3_female_names = top3_female_names.set_index("Name")

# Rename count colums
top3_female_names = top3_female_names.rename(columns={'Count 1991': '1991', 'Count 1992': '1992', 'Count 1993':'1993',
                                                   'Count 1994': '1994', 'Count 1995': '1995', 'Count 1996': '1996',
                                                   'Count 1997': '1997', 'Count 1998': '1998', 'Count 1999': '1999', 
                                                   'Count 2000': '2000', 'Count 2001': '2001', 'Count 2002':'2002', 
                                                   'Count 2003': '2003', 'Count 2004': '2004', 'Count 2005': '2005',
                                                   'Count 2006': '2006', 'Count 2007': '2007', 'Count 2008': '2008', 
                                                   'Count 2009': '2009', 'Count 2010': '2010', 'Count 2011': '2011', 
                                                   'Count 2012': '2012', 'Count 2013': '2013', 'Count 2014': '2014', 
                                                   'Count 2015': '2015', 'Count 2016': '2016', 'Count 2017': '2017', 
                                                   'Count 2018': '2018'})

top3_female_names

# Collect the years where the data was collected
yearly_count= top3_female_names
years= yearly_count.keys()

# Tyrion total count line
top3_female_names.loc['Arya', "1991":"2018"].plot(label="Arya")
plt.legend()

# Ramsay total count line
top3_female_names.loc['Khaleesi', "1991":"2018"].plot(label="Khaleesi")
plt.legend()

# Theon total count line

top3_female_names.loc['Meera', "1991":"2018"].plot(label="Meera")
plt.legend()

# Add labels and title
plt.title('TOP 3 "GOT" Female Names')
plt.xlabel("Years")
plt.ylabel("Total Count")

# Show the chart
plt.show()

# %%
# Total male GOT names

male_names_total.sum(axis = 0, skipna = True)
# Out:
# Total Count    1304.0
# dtype: float64

# %%
# Total female GOT names

female_names_total.sum(axis = 0, skipna = True)
# Out:
# Total Count    23163.0
# dtype: float64

# %%
# Create a pie chart to show name popularity by gender
labels = ["Male Names", "Female Names"] 

# Copied corresponding total values from above
names_count = [1304,23163]    
colors = ["lightskyblue", "lightcoral"]
explode = (0, 0.3) 

# Tell matplotlib to create a pie chart based upon the above data
plt.title('"GOT" Names Popularity by Gender')
plt.pie(names_count, explode=explode, labels=labels, colors=colors, 
                         autopct="%1.1f%%", shadow=True, startangle=145)
plt.legend(labels, loc = 'best')

# Display pie chart
plt.show()

# %%
# Copy male_names_df to a new df
male_names_yearly = male_names_df

# Add total number GOT male names for each year
male_names_yearly.loc['Total',:]= male_names_yearly.sum(axis=0)

# Drop "Name" and "Gender" column
# Print "Count" for each year only
male_names_yearly.drop(columns=['Name', 'Gender'])

male_names_yearly_data = male_names_yearly.iloc[-1, 2:-1]
yearly_male_data = pd.DataFrame(data=male_names_yearly_data)
#yearly_male_data

# %%
# Copy female_names_df to a new df
female_names_yearly = female_names_df

# Add total number GOT female names for each year
female_names_yearly.loc['Total',:]= female_names_yearly.sum(axis=0)

# Drop "Name" and "Gender" column
# Print "Count" for each year only
female_names_yearly.drop(columns=['Name', 'Gender'])

female_names_yearly_data = female_names_yearly.iloc[-1, 2:-1]
yearly_female_data = pd.DataFrame(data=female_names_yearly_data)
#yearly_female_data

# %%
# Combine yearly_male_data and yearly_female_data
yearly_name_total = yearly_male_data['Total'] + yearly_female_data['Total']
yearly_name_total = pd.DataFrame(data=yearly_name_total)
yearly_name_total
# Out:
#            Total
# Count 1991   110
# Count 1992   111
# Count 1993    91
# Count 1994    91
# Count 1995   103
# Count 1996   135
# Count 1997   179
# Count 1998   173
# Count 1999   149
# Count 2000   193
# Count 2001   198
# Count 2002   262
# Count 2003   294
# Count 2004   354
# Count 2005   320
# Count 2006   262
# Count 2007   458
# Count 2008   504
# Count 2009   524
# Count 2010   555
# Count 2011   695
# Count 2012  1221
# Count 2013  1871
# Count 2014  2467
# Count 2015  2580
# Count 2016  3024
# Count 2017  3509
# Count 2018  4034

# %%
# Line or Scatter plot for 1991 to 2018 (ENTIRE GOT CAREER)
# A scatter plot requires numeric values for both x and y

# X-axis - Years(1991 to 2018)
# Y - axis - Total Count over the years

# Define Years (x-axis)
years= list(top3_female_names.columns.values)
years.remove("Gender")
years.remove("Total Count")

# Years = 1991 to 2018
years

# Define Total Count (y-axis)
# total_count is the list of total counts from above table
total_count = yearly_name_total["Total"].tolist()
total_count

# Plot Years vs Total Count
plt.scatter(years, total_count)

# Add labels and title
plt.title('Total Count of GOT Names Each Year (1991-2018)')
plt.xlabel("Years")
plt.ylabel("Total Count")

# Display x-axis labels vertically for legibility
plt.xticks(rotation=90)

# Display scatter plot
plt.show()

# %%
# Line or Scatter plot for 1991 to 2010 (GOT BOOK)
# X-axis - Years(1991 to 2010)
# Y - axis - Total Count over the years

# X-axis - Years(1991 to 2010)
# Y - axis - Total Count over the years

# Years = 1991 to 2010
book_years = years
del book_years[20:28]

# Define Total Count (y-axis)
# total_count is the list of total counts from above table ONLY for years 1991 to 2010
book_total_count = yearly_name_total["Total"].tolist()
del book_total_count[20:28]

# Plot Years vs Total Count
plt.scatter(book_years, book_total_count)

# Add labels and title
plt.title('Total Count of GOT Names Each Year (1991-2010)')
plt.xlabel("Years")
plt.ylabel("Total Count")

# Display x-axis labels vertically for legibility
plt.xticks(rotation=90)

# Display scatter plot
plt.show()

# %%
# Line or Scatter plot for 2006 to 2018 (GOT SHOW)
# X-axis - Years(2006 to 2018)
# Y - axis - Total Count over the years

# Years = 2006 to 2018
show_years= list(top3_female_names.columns.values)
show_years.remove("Gender")
show_years.remove("Total Count")
del show_years[0:15]

# Define Total Count (y-axis)
# total_count is the list of total counts from above table ONLY for years 2006 to 2018
show_total_count = yearly_name_total["Total"].tolist()
del show_total_count[0:15]

# Plot Years vs Total Count
plt.scatter(show_years, show_total_count)

# Add labels and title
plt.title('Total Count of GOT Names Each Year (2006 to 2018)')
plt.xlabel("Years")
plt.ylabel("Total Count")

# Display x-axis labels vertically for legibility
plt.xticks(rotation=90)

# Display scatter plot
plt.show()
